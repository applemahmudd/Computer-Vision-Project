# %% [markdown]
# <a href="https://colab.research.google.com/github/applemahmudd/Computer-Vision-Project/blob/main/Track_Object_from_Custom_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="wmqfIhyN0xpVNbaOhfmc")
project = rf.workspace("hng").project("car-uvjtt")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 47.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 73.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Car-5 in yolov11:: 100%|██████████| 430/430 [00:00<00:00, 10231.05it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 44.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolo11n.pt data={dataset.location}/data.yaml epochs=5 imgsz=640
# Out:
# Ultralytics 8.3.253 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=track model=yolo11n.pt source= /content/Traffic.mp4 conf=0.25 save=True tracker=bytetrack.yaml
# Out:
# Ultralytics 8.3.253 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# video 1/1 (frame 1/1501) /content/Traffic.mp4: 384x640 12 cars, 74.2ms
# video 1/1 (frame 2/1501) /content/Traffic.mp4: 384x640 11 cars, 11.0ms
# video 1/1 (frame 3/1501) /content/Traffic.mp4: 384x640 11 cars, 1 truck, 13.2ms
# video 1/1 (frame 4/1501) /content/Traffic.mp4: 384x640 9 cars, 1 truck, 10.5ms
# video 1/1 (frame 5/1501) /content/Traffic.mp4: 384x640 8 cars, 1 truck, 10.7ms
# video 1/1 (frame 6/1501) /content/Traffic.mp4: 384x640 10 cars, 1 truck, 11.6ms
# video 1/1 (frame 7/1501) /content/Traffic.mp4: 384x640 12 cars, 11.7ms
# video 1/1 (frame 8/1501) /content/Traffic.mp4: 384x640 10 cars, 10.9ms
# video 1/1 (frame 9/1501) /content/Traffic.mp4: 384x640 9 cars, 1 truck, 10.6ms
# video 1/1 (frame 10/1501) /content/Traffic.mp4: 384x640 12 cars, 13.2ms
# ...
