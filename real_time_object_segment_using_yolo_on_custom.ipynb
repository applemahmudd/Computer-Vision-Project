# %% [markdown]
# <a href="https://colab.research.google.com/github/applemahmudd/Computer-Vision-Project/blob/main/real_time_object_segment_using_yolo_on_custom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="wmqfIhyN0xpVNbaOhfmc")
project = rf.workspace("roboflow-universe-projects").project("fire-and-smoke-segmentation")
version = project.version(6)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 83.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 133.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Fire-and-Smoke-Segmentation-6 in yolov11:: 100%|██████████| 14232/14232 [00:03<00:00, 4245.79it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=segment mode=train model=yolo11n-seg.pt data={dataset.location}/data.yaml epochs=5 imgsz=640
# Out:
# ...
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=segment mode=predict model=/content/runs/segment/train/weights/best.pt source=/content/Fire-and-Smoke-Segmentation-6/test/images save=True
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-seg summary (fused): 113 layers, 2,834,958 parameters, 0 gradients, 9.6 GFLOPs
#
# image 1/20 /content/Fire-and-Smoke-Segmentation-6/test/images/flare_0014_jpg.rf.74f970ef7f276751cfa312c22dfcc5de.jpg: 640x640 1 fire, 1 smoke, 22.4ms
# image 2/20 /content/Fire-and-Smoke-Segmentation-6/test/images/flare_0028_jpg.rf.931ef592dcd4fedef2fb22effaf4a325.jpg: 640x640 2 fires, 10.0ms
# image 3/20 /content/Fire-and-Smoke-Segmentation-6/test/images/flare_0029_jpg.rf.80711e6faf9d9d48064c8b37e11cf52f.jpg: 640x640 1 fire, 4 smokes, 9.9ms
# image 4/20 /content/Fire-and-Smoke-Segmentation-6/test/images/flare_0057_jpg.rf.b9157dd927c01b0be7d4cf23fe33dcbe.jpg: 640x640 1 fire, 9.9ms
# image 5/20 /content/Fire-and-Smoke-Segmentation-6/test/images/flare_0058_jpg.rf.7f6b38a665dddf45c5d813647749841b.jpg: 640x640 1 fire, 1 smoke, 9.9ms
# ...
