# %% [markdown]
# <a href="https://colab.research.google.com/github/applemahmudd/Computer-Vision-Project/blob/main/Track.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model= model = YOLO("yolo11n.pt")

# %%
result=model.track("/content/Traffic.mp4", save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1501) /content/Traffic.mp4: 384x640 12 cars, 174.9ms
# video 1/1 (frame 2/1501) /content/Traffic.mp4: 384x640 12 cars, 142.5ms
# video 1/1 (frame 3/1501) /content/Traffic.mp4: 384x640 11 cars, 1 truck, 197.8ms
# video 1/1 (frame 4/1501) /content/Traffic.mp4: 384x640 11 cars, 1 truck, 186.4ms
# video 1/1 (frame 5/1501) /content/Traffic.mp4: 384x640 11 cars, 1 truck, 193.2ms
# ...

# %%
result[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>

# %%
from ultralytics import YOLO

# %%
model= model = YOLO("yolo11n.pt")

# %%
video= model.track("/content/Traffic.mp4",save= True)
