# %% [markdown]
# <a href="https://colab.research.google.com/github/applemahmudd/Computer-Vision-Project/blob/main/Pose_estimate_from_custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="wmqfIhyN0xpVNbaOhfmc")
project = rf.workspace("projete3104").project("postura_ia_ofc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 90.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 127.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Postura_IA_ofc-1 in yolov8:: 100%|██████████| 148/148 [00:00<00:00, 8144.17it/s]

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.5 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=pose mode=train data={dataset.location}/data.yaml epochs=5 imgsz=640 batch=16
# Out:
# ...
# Ultralytics 8.4.0 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=pose mode=predict model=/content/runs/pose/train/weights/best.pt source=/content/123.mp4 conf=0.25 save=True
# Out:
# Ultralytics 8.4.0 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO26n-pose summary (fused): 132 layers, 2,522,340 parameters, 0 gradients, 5.7 GFLOPs
#
# video 1/1 (frame 1/300) /content/123.mp4: 384x640 (no detections), 64.8ms
# video 1/1 (frame 2/300) /content/123.mp4: 384x640 (no detections), 14.1ms
# video 1/1 (frame 3/300) /content/123.mp4: 384x640 (no detections), 13.4ms
# video 1/1 (frame 4/300) /content/123.mp4: 384x640 (no detections), 14.0ms
# video 1/1 (frame 5/300) /content/123.mp4: 384x640 (no detections), 13.1ms
# video 1/1 (frame 6/300) /content/123.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (frame 7/300) /content/123.mp4: 384x640 (no detections), 19.7ms
# video 1/1 (frame 8/300) /content/123.mp4: 384x640 (no detections), 15.4ms
# video 1/1 (frame 9/300) /content/123.mp4: 384x640 (no detections), 13.6ms
# video 1/1 (frame 10/300) /content/123.mp4: 384x640 (no detections), 11.8ms
# ...
